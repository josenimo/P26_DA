# %%
import pandas as pd
import anndata as ad
from loguru import logger 
import time

import numpy as np
import tifffile

import matplotlib.pyplot as plt
import seaborn as sns

import shapely
import geopandas as gpd

import os
import sys
sys.path.append(os.path.abspath('../scripts'))
import utils
import importlib

import scimap as sm

# %%
sample_id = 992

# %%
path_to_quant = f"../data/quantification/{sample_id}_backsub_quantification.csv"
path_to_geojson = f"../data/geojsons/{sample_id}.geojson"
path_to_gates = "../data/phenotyping/20240911_gates.csv"

# %%
adata = utils.read_quant(path_to_quant)
# Out:
# 2024-09-17 11:19:36.225 | INFO     | utils:read_quant:21 -  ---- read_quant : version number 1.0.0 ----
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning:
#
# Transforming to str index.
#
# 2024-09-17 11:19:42.249 | INFO     | utils:read_quant:40 -  1134347 cells and 75 variables
# 2024-09-17 11:19:42.250 | INFO     | utils:read_quant:41 -  ---- read_quant is done, took 6s  ----

# %%
adata = utils.filter_by_annotation(adata, path_to_geojson=path_to_geojson)
# Out:
# 2024-09-17 11:19:52.320 | INFO     | utils:filter_by_annotation:161 -  ---- filter_by_annotation : version number 1.0.0 ----
# 2024-09-17 11:19:52.422 | INFO     | utils:filter_by_annotation:167 - GeoJson loaded, detected: 19 annotations
# 2024-09-17 11:23:02.590 | INFO     | utils:filter_by_annotation:176 - Labelled cells with annotations if they were found inside
# 2024-09-17 11:23:03.848 | INFO     | utils:filter_by_annotation:205 -  ---- filter_by_annotation is done, took 191s  ----

# %%
# Plot the density plot for each column
plt.figure(figsize=(8,6))
tmp_df = np.log10(pd.DataFrame(adata.X, columns=adata.var_names))
sns.kdeplot(tmp_df['mean_DAPI_bg'], label='mean_DAPI_bg', color='blue')
sns.kdeplot(tmp_df['mean_DAPI_1'], label='mean_DAPI_1', color='green')
sns.kdeplot(tmp_df['mean_DAPI_2'], label='mean_DAPI_2', color='red')

low_threshold = 2.3
plt.axvline(low_threshold, color='black', linestyle='--', alpha=0.5)
print(f"Threshold for DAPI intensity: {10**low_threshold:.2f}")

high_threshold = 3.45
plt.axvline(high_threshold, color='black', linestyle='--', alpha=0.5)
print(f"Threshold for DAPI intensity: {10**high_threshold:.2f}")

plt.title('Overlay of DAPI intensities')
plt.legend()
plt.show()
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning:
#
# divide by zero encountered in log10
# Threshold for DAPI intensity: 199.53
# Threshold for DAPI intensity: 2818.38

# %%
adata = utils.filter_by_abs_value(adata=adata, marker="mean_DAPI_bg", value=199, direction="above")
adata = utils.filter_by_abs_value(adata=adata, marker="mean_DAPI_bg", value=2818, direction="below")
# Out:
# 2024-09-17 11:25:39.290 | INFO     | utils:filter_by_abs_value:212 -  ---- filter_by_abs_value : version number 1.0.0 ----
# 2024-09-17 11:25:39.368 | INFO     | utils:filter_by_abs_value:228 - Number of cells with mean_DAPI_bg above 199: 1107908
# 2024-09-17 11:25:40.153 | INFO     | utils:filter_by_abs_value:250 -  ---- filter_by_abs_value is done, took 0s  ----
# 2024-09-17 11:25:40.153 | INFO     | utils:filter_by_abs_value:212 -  ---- filter_by_abs_value : version number 1.0.0 ----
# 2024-09-17 11:25:40.194 | INFO     | utils:filter_by_abs_value:233 - Number of cells with mean_DAPI_bg below 2818: 1131162
# 2024-09-17 11:25:40.904 | INFO     | utils:filter_by_abs_value:250 -  ---- filter_by_abs_value is done, took 0s  ----

# %%
sns.histplot(adata.obs['Area'], bins=350)
plt.yscale('log')
plt.xscale('log')
plt.title('Area distribution')
plt.xlabel('Area (pixels)')
plt.axvline(400, color='red', linestyle='--')
plt.axvline(5000, color='red', linestyle='--')
plt.show()

# %%
adata.obs['Area_filter_nottoobig'] = adata.obs['Area'] < 5000
adata.obs['Area_filter_nottoolow'] = adata.obs['Area'] > 400
adata.obs['Area_filter'] = adata.obs['Area_filter_nottoobig'] & adata.obs['Area_filter_nottoolow']

#print stats
print("Number of cells before filtering: ", adata.shape[0])
print("Number of cells filtered out by Area: ", adata.shape[0] - adata.obs['Area_filter'].sum())
print("Percentage of cells filtered out by Area: ", round((adata.shape[0] - adata.obs['Area_filter'].sum())/adata.shape[0]*100, 3), "%")
# Out:
# Number of cells before filtering:  1134347
# Number of cells filtered out by Area:  4417
# Percentage of cells filtered out by Area:  0.389 %

# %%
adata = utils.filter_by_ratio(
    adata=adata, 
    end_cycle="mean_DAPI_2", 
    start_cycle="mean_DAPI_bg", 
    label="DAPI",
    min_ratio=0.15,
    max_ratio=1.05,
    )
# Out:
# 2024-09-17 11:26:16.612 | INFO     | utils:filter_by_ratio:111 -  ---- filter_by_ratio : version number 1.1.0 ----
# 2024-09-17 11:26:16.696 | INFO     | utils:filter_by_ratio:129 - Number of cells with DAPI ratio < 0.15: 36285
# 2024-09-17 11:26:16.735 | INFO     | utils:filter_by_ratio:130 - Number of cells with DAPI ratio > 1.05: 1618
# 2024-09-17 11:26:16.774 | INFO     | utils:filter_by_ratio:131 - Number of cells with DAPI ratio between 0.15 and 1.05: 1095999
# 2024-09-17 11:26:16.816 | INFO     | utils:filter_by_ratio:132 - Percentage of cells filtered out: 3.38%
# 2024-09-17 11:26:19.288 | INFO     | utils:filter_by_ratio:152 -  ---- filter_by_ratio is done, took 2s  ----

# %%
adata = adata[adata.obs['filter_by_ann'].astype(bool) & adata.obs['mean_DAPI_bg_abs_below_value'] & adata.obs['mean_DAPI_bg_abs_above_value'] & adata.obs['Area_filter'] & adata.obs['DAPI_ratio_pass']]

# %%
sns.scatterplot(data=adata.obs, x='X_centroid', y='Y_centroid', linewidth=0, s=2, alpha=0.5)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.gca().invert_yaxis()
plt.show()

# %%
gates = utils.read_gates(path_to_gates)
gates = gates[gates['sample_id']==sample_id]
adata.obs['imageid'] = str(sample_id)
processed_gates = utils.process_gates_for_sm(gates, sample_id=str(sample_id))
# Out:
# 2024-09-17 11:28:07.605 | INFO     | utils:read_gates:48 -  ---- read_gates : version number 1.0.0 ----
# 2024-09-17 11:28:07.610 | INFO     | utils:read_gates:53 -    Filtering out all rows with value 0.0 (assuming not gated)
# 2024-09-17 11:28:07.612 | INFO     | utils:read_gates:56 -   Found 78 valid gates
# 2024-09-17 11:28:07.612 | INFO     | utils:read_gates:58 -  ---- read_gates is done, took 0s  ----
# /var/folders/x7/grkjlk8s223dy6234rnz1885mxz2_6/T/ipykernel_71374/2216073073.py:3: ImplicitModificationWarning:
#
# Trying to modify attribute `.obs` of view, initializing view as actual.
#
# 2024-09-17 11:28:08.515 | INFO     | utils:process_gates_for_sm:77 -  ---- process_gates_for_sm : version number 1.0.0 ----
# /Users/jnimoca/Jose_BI/P26_DA/scripts/utils.py:82: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2024-09-17 11:28:08.517 | INFO     | utils:process_gates_for_sm:84 -  ---- process_gates_for_sm is done, took 0s  ----

# %%
adata = adata[:, adata.var_names.str.contains("mean")]
sm.pl.markerCorrelation(adata, figsize=(6,5), layer=None)

# %%
#remove not gated channels
adata = adata[:, adata.var_names.isin(processed_gates['marker'])]
sm.pl.markerCorrelation(adata, figsize=(6,5), layer=None)

# %%
#special case with this one since I could not find any CD8 marker
CD8_dict = {
    "sample_id": "992",
    "marker_id": "mean_CD8",
# Out:
#      sample_id      marker_id  gate_value  log1p_gate_value
# 320        992  mean_Vimentin  231.632770          5.449461
# 321        992      mean_CD3e  350.000000          5.860786
# 322        992     mean_panCK  425.598413          6.055843
# 325        992    mean_COL1A1  771.258565          6.649319
# 326        992      mean_CD20  577.563846          6.360549
# 327        992      mean_CD68  250.000000          5.525453
# 328        992      mean_Ki67   11.854957          2.553730

# %%
adata.raw = adata
adata = sm.pp.log1p(adata)
adata = sm.pp.rescale(adata, gate=processed_gates, log=True, verbose=True)
path_to_phenotype_matrix = "../data/phenotyping/20240905_PhenotypeMatrix_v3.csv"
phenotype_matrix = pd.read_csv(path_to_phenotype_matrix)
adata = sm.tl.phenotype_cells (adata, phenotype=phenotype_matrix, label="phenotype")
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/preprocessing/rescale.py:105: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Scaling Image 992
# Scaling mean_Vimentin
# Scaling mean_CD3e
# Scaling mean_panCK
# Scaling mean_COL1A1
# Scaling mean_CD20
# Scaling mean_CD68
# Scaling mean_Ki67
# Phenotyping Cancer_cells
# Phenotyping T_cells
# Phenotyping Vimentin_cells
# Phenotyping COL1A1_cells
# Phenotyping B_cells
# Phenotyping Macrophages
# -- Subsetting T_cells
# Phenotyping CD4_Tcells
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 6
#       4 path_to_phenotype_matrix = "../data/phenotyping/20240905_PhenotypeMatrix_v3.csv"
#       5 phenotype_matrix = pd.read_csv(path_to_phenotype_matrix)
# ----> 6 adata = sm.tl.phenotype_cells (adata, phenotype=phenotype_matrix, label="phenotype")
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:281, in phenotype_cells(adata, phenotype, gate, label, imageid, pheno_threshold_percent, pheno_threshold_abs, verbose)
#     279             if verbose:
#     280                 print("-- Subsetting " + str(i))
# --> 281             phenotype_l = pd.DataFrame(phenotype_cells(data = d, group = i, phenotype=phenotype, gate=gate), columns = [i])
#     282             phenotype_labels = phenotype_labels.merge(phenotype_l, how='outer', left_index=True, right_index=True)
#     284 # Rearrange the rows back to original
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:208, in phenotype_cells.<locals>.phenotype_cells(data, phenotype, gate, group)
#     203     #return total_score, pos_fail, neg_fail
#     204
#     205
#     206 # Apply the fuction to get the total score for all cell types
#     207 r_prob_mapper = lambda x: prob_mapper (data=data, all_phenotype=all_phenotype, cell=x, gate=gate) # Create lamda function
# --> 208 final_scores = list(map(r_prob_mapper, [*all_phenotype])) # Apply function
#     209 final_scores = dict(zip([*all_phenotype], final_scores)) # Name the lists
#     211 # Combine the final score to annotate the cells with a label
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:207, in phenotype_cells.<locals>.phenotype_cells.<locals>.<lambda>(x)
#     202     return {cell: total_score, 'pos_fail': pos_fail ,'neg_fail': neg_fail}
#     203     #return total_score, pos_fail, neg_fail
#     204
#     205
#     206 # Apply the fuction to get the total score for all cell types
# --> 207 r_prob_mapper = lambda x: prob_mapper (data=data, all_phenotype=all_phenotype, cell=x, gate=gate) # Create lamda function
#     208 final_scores = list(map(r_prob_mapper, [*all_phenotype])) # Apply function
#     209 final_scores = dict(zip([*all_phenotype], final_scores)) # Name the lists
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:158, in phenotype_cells.<locals>.phenotype_cells.<locals>.prob_mapper(data, all_phenotype, cell, gate)
#     156 # Negative marker score
#     157 if len(neg) != 0:
# --> 158     neg_score = (1-data[neg]).mean(axis=1).values
#     159     neg_fail = list(map(r_gate_satisfation_morethan, neg)) if len(neg) > 1 else []
#     160     neg_fail = np.amax(neg_fail, axis=0) if len(neg) > 1 else []
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['mean_CD8'], dtype='object')] are in the [columns]"

# %%
adata.obs.phenotype.value_counts()

# %%
custom_colours = {
    "Cancer_cells" : "red",
    "CD4_Tcells" : "peru",
    "CD8_Tcells" : "lawngreen",
    "Macrophages" : "yellow",
    "COL1A1_cells" : "deepskyblue",
    "Vimentin_cells" : "orange",
    "B_cells" : "black",
    "Unknown" : "whitesmoke"
}

# %%
sm.pl.spatial_scatterPlot (adata, colorBy = ['phenotype'],figsize=(12,7), s=2, fontsize=10, customColors=custom_colours)
