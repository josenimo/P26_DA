# %%
import pandas as pd
import anndata as ad
from loguru import logger 
import time

import numpy as np
import tifffile

import matplotlib.pyplot as plt
import seaborn as sns

import shapely
import geopandas as gpd

import os
import sys
sys.path.append(os.path.abspath('../scripts'))
import utils
import importlib

import scimap as sm
# Out:
# Running SCIMAP  2.1.3

# %%
sample_id = 999

# %%
path_to_quant = f"../data/quantification/{sample_id}_backsub_quantification.csv"
path_to_geojson = f"../data/geojsons/{sample_id}.geojson"
path_to_gates = "../data/phenotyping/20240918_gates.csv"
path_to_phenotype_matrix = "../data/phenotyping/20240905_PhenotypeMatrix_v3.csv"
phenotype_matrix = pd.read_csv(path_to_phenotype_matrix)

# %%
custom_colours = {
    "Cancer_cells" : "red",
    "CD4_Tcells" : "peru",
    "CD8_Tcells" : "lawngreen",
    "Macrophages" : "yellow",
    "COL1A1_cells" : "deepskyblue",
    "Vimentin_cells" : "orange",
    "B_cells" : "black",
    "Unknown" : "whitesmoke"
}

# %%
adata = utils.read_quant(path_to_quant)
adata
# Out:
# 2024-09-18 21:12:31.423 | INFO     | utils:read_quant:24 -  ---- read_quant : version number 1.0.0 ----
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning:
#
# Transforming to str index.
#
# 2024-09-18 21:12:32.278 | INFO     | utils:read_quant:43 -  169441 cells and 75 variables
# 2024-09-18 21:12:32.278 | INFO     | utils:read_quant:44 -  ---- read_quant is done, took 0s  ----
# AnnData object with n_obs × n_vars = 169441 × 75
#     obs: 'CellID', 'Y_centroid', 'X_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Orientation', 'Extent', 'Solidity'
#     var: 'math', 'marker'

# %%
adata = utils.filter_by_annotation(adata, path_to_geojson=path_to_geojson)
# Out:
# 2024-09-18 21:12:32.286 | INFO     | utils:filter_by_annotation:161 -  ---- filter_by_annotation : version number 1.2.0 ----
# 2024-09-18 21:12:32.323 | INFO     | utils:filter_by_annotation:167 - GeoJson loaded, detected: 3 annotations
# 2024-09-18 21:12:36.626 | INFO     | utils:filter_by_annotation:179 - Labelled cells with annotations if they were found inside
# 2024-09-18 21:12:36.632 | INFO     | utils:filter_by_annotation:180 - Number of cells not found inside any annotation: 163548
# 2024-09-18 21:12:36.975 | INFO     | utils:filter_by_annotation:212 -  ---- filter_by_annotation is done, took 4s  ----

# %%
# Plot the density plot for each column
plt.figure(figsize=(8,6))
tmp_df = np.log10(pd.DataFrame(adata.X, columns=adata.var_names))
sns.kdeplot(tmp_df['mean_DAPI_bg'], label='mean_DAPI_bg', color='blue')
sns.kdeplot(tmp_df['mean_DAPI_1'], label='mean_DAPI_1', color='green')
sns.kdeplot(tmp_df['mean_DAPI_2'], label='mean_DAPI_2', color='red')

low_threshold = 2
plt.axvline(low_threshold, color='black', linestyle='--', alpha=0.5)
print(f"Threshold for DAPI intensity: {10**low_threshold:.2f}")

high_threshold = 3.1
plt.axvline(high_threshold, color='black', linestyle='--', alpha=0.5)
print(f"Threshold for DAPI intensity: {10**high_threshold:.2f}")

plt.title('Overlay of DAPI intensities')
plt.legend()
plt.show()
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning:
#
# divide by zero encountered in log10
# Threshold for DAPI intensity: 100.00
# Threshold for DAPI intensity: 1258.93

# %%
adata = utils.filter_by_abs_value(adata=adata, marker="mean_DAPI_bg", value=100, direction="above")
adata = utils.filter_by_abs_value(adata=adata, marker="mean_DAPI_bg", value=1260, direction="below")
# Out:
# 2024-09-18 21:12:46.111 | INFO     | utils:filter_by_abs_value:218 -  ---- filter_by_abs_value : version number 1.0.0 ----
# 2024-09-18 21:12:46.124 | INFO     | utils:filter_by_abs_value:234 - Number of cells with mean_DAPI_bg above 100: 99067
# 2024-09-18 21:12:46.725 | INFO     | utils:filter_by_abs_value:256 -  ---- filter_by_abs_value is done, took 0s  ----
# 2024-09-18 21:12:46.726 | INFO     | utils:filter_by_abs_value:218 -  ---- filter_by_abs_value : version number 1.0.0 ----
# 2024-09-18 21:12:46.734 | INFO     | utils:filter_by_abs_value:239 - Number of cells with mean_DAPI_bg below 1260: 165723
# 2024-09-18 21:12:47.177 | INFO     | utils:filter_by_abs_value:256 -  ---- filter_by_abs_value is done, took 0s  ----

# %%
sns.histplot(adata.obs['Area'], bins=350)
plt.yscale('log')
plt.xscale('log')
plt.title('Area distribution')
plt.xlabel('Area (pixels)')
plt.axvline(400, color='red', linestyle='--')
plt.axvline(5000, color='red', linestyle='--')
plt.show()

# %%
adata.obs['Area_filter_nottoobig'] = adata.obs['Area'] < 5000
adata.obs['Area_filter_nottoolow'] = adata.obs['Area'] > 400
adata.obs['Area_filter'] = adata.obs['Area_filter_nottoobig'] & adata.obs['Area_filter_nottoolow']

#print stats
print("Number of cells before filtering: ", adata.shape[0])
print("Number of cells filtered out by Area: ", adata.shape[0] - adata.obs['Area_filter'].sum())
print("Percentage of cells filtered out by Area: ", round((adata.shape[0] - adata.obs['Area_filter'].sum())/adata.shape[0]*100, 3), "%")
# Out:
# Number of cells before filtering:  169441
# Number of cells filtered out by Area:  1819
# Percentage of cells filtered out by Area:  1.074 %

# %%
adata = utils.filter_by_ratio(
    adata=adata, 
    end_cycle="mean_DAPI_2", 
    start_cycle="mean_DAPI_bg", 
    label="DAPI",
    min_ratio=0.27,
    max_ratio=1.20,
    )
# Out:
# 2024-09-18 21:12:52.426 | INFO     | utils:filter_by_ratio:114 -  ---- filter_by_ratio : version number 1.1.0 ----
# 2024-09-18 21:12:52.440 | INFO     | utils:filter_by_ratio:132 - Number of cells with DAPI ratio < 0.27: 828
# 2024-09-18 21:12:52.450 | INFO     | utils:filter_by_ratio:133 - Number of cells with DAPI ratio > 1.2: 8216
# 2024-09-18 21:12:52.459 | INFO     | utils:filter_by_ratio:134 - Number of cells with DAPI ratio between 0.27 and 1.2: 160337
# 2024-09-18 21:12:52.467 | INFO     | utils:filter_by_ratio:135 - Percentage of cells filtered out: 5.37%
# 2024-09-18 21:12:53.213 | INFO     | utils:filter_by_ratio:155 -  ---- filter_by_ratio is done, took 0s  ----

# %%
adata = adata[adata.obs['filter_by_ann'].astype(bool) & adata.obs['mean_DAPI_bg_abs_below_value'] & adata.obs['mean_DAPI_bg_abs_above_value'] & adata.obs['Area_filter'] & adata.obs['DAPI_ratio_pass']]

# %%
sns.scatterplot(data=adata.obs, x='X_centroid', y='Y_centroid', linewidth=0, s=2, alpha=0.5)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.gca().invert_yaxis()
plt.show()

# %%
gates = utils.read_gates(path_to_gates)
gates = gates[gates['sample_id']==sample_id]
adata.obs['imageid'] = str(sample_id)
processed_gates = utils.process_gates_for_sm(gates, sample_id=str(sample_id))
# Out:
# 2024-09-18 21:13:12.009 | INFO     | utils:read_gates:51 -  ---- read_gates : version number 1.0.0 ----
# 2024-09-18 21:13:12.014 | INFO     | utils:read_gates:56 -    Filtering out all rows with value 0.0 (assuming not gated)
# 2024-09-18 21:13:12.016 | INFO     | utils:read_gates:59 -   Found 79 valid gates
# 2024-09-18 21:13:12.016 | INFO     | utils:read_gates:61 -  ---- read_gates is done, took 0s  ----
# /var/folders/x7/grkjlk8s223dy6234rnz1885mxz2_6/T/ipykernel_42117/2216073073.py:3: ImplicitModificationWarning:
#
# Trying to modify attribute `.obs` of view, initializing view as actual.
#
# 2024-09-18 21:13:12.048 | INFO     | utils:process_gates_for_sm:80 -  ---- process_gates_for_sm : version number 1.0.0 ----
# /Users/jnimoca/Jose_BI/P26_DA/scripts/utils.py:85: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2024-09-18 21:13:12.050 | INFO     | utils:process_gates_for_sm:87 -  ---- process_gates_for_sm is done, took 0s  ----

# %%
adata = adata[:, processed_gates['marker']]

# %%
adata_copy = adata.copy()
adata_copy.raw = adata_copy
adata_copy = sm.pp.log1p(adata_copy)
adata_copy = sm.pp.rescale(adata_copy, gate=processed_gates, log=True, verbose=True)
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/preprocessing/rescale.py:105: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Scaling Image 999
# Scaling mean_Vimentin
# Scaling mean_CD3e
# Scaling mean_panCK
# Scaling mean_CD8
# Scaling mean_COL1A1
# Scaling mean_CD20
# Scaling mean_CD68
# Scaling mean_Ki67

# %%
adata_copy = sm.tl.phenotype_cells (adata_copy, phenotype=phenotype_matrix, label="phenotype")
sm.pl.spatial_scatterPlot (adata_copy, colorBy = ['phenotype'],figsize=(12,7), s=1, fontsize=10, customColors=custom_colours)
# Out:
# Phenotyping Cancer_cells
# Phenotyping T_cells
# Phenotyping Vimentin_cells
# Phenotyping COL1A1_cells
# Phenotyping B_cells
# Phenotyping Macrophages
# -- Subsetting T_cells
# Phenotyping CD4_Tcells
# Phenotyping CD8_Tcells
# Consolidating the phenotypes across all groups
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:290: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/scimap/lib/python3.10/site-packages/scimap/tools/phenotype_cells.py:290: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
