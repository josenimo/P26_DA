# %% [markdown]
# # Context

# %%
# !mamba list
# Out:
# # packages in environment at /opt/homebrew/Caskroom/mambaforge/base/envs/scimap:
# #
# # Name                    Version                   Build  Channel
# aicsimageio               4.11.0                   pypi_0    pypi
# aiobotocore               2.15.0                   pypi_0    pypi
# aiohappyeyeballs          2.4.0                    pypi_0    pypi
# aiohttp                   3.10.5                   pypi_0    pypi
# aioitertools              0.12.0                   pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# alabaster                 1.0.0                    pypi_0    pypi
# anndata                   0.10.9                   pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.4.0                    pypi_0    pypi
# app-model                 0.2.8                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# ...

# %% [markdown]
# Goal: To export an anndata object for us to add to the spatialdata object

# %% [markdown]
# # Content

# %% [markdown]
# ## Imports

# %%
import anndata as ad

# %% [markdown]
# ## Load data

# %%
adata = ad.read_h5ad("../data/processed/20241002_1218_991_phenotyped.h5ad")

# %%
adata.obs
# Out:
#         CellID    Y_centroid    X_centroid    Area  MajorAxisLength  \
# 0            0  29410.806452  35874.857801  1519.0        98.696620
# 1            1  29445.080408  36162.243140  1567.0        50.422862
# 2            2  29505.171707  38455.235122  1025.0        40.280587
# 3            3  29539.721673  35060.844867  1315.0        61.049935
# 4            4  29982.642779  36765.660558  3656.0        84.178897
# ...        ...           ...           ...     ...              ...
# 685800  685800  40389.067593  46087.962963  1080.0        56.372404
# 685801  685801  40382.629182  47716.017658  1076.0        41.856049
# 685802  685802  40382.072917  48436.798177   768.0        33.256837
# 685803  685803  40383.786948  45011.021113  1042.0        45.051210
# 685804  685804  40381.744269  45377.274355  1396.0        54.635806
#
#         MinorAxisLength  Eccentricity  Orientation      Extent  Solidity  ...  \
# ...

# %%
adata.var
# Out:
#                math    marker
# mean_Vimentin  mean  Vimentin
# mean_CD3e      mean      CD3e
# mean_panCK     mean     panCK
# mean_CD8       mean       CD8
# mean_COL1A1    mean    COL1A1
# mean_CD20      mean      CD20
# mean_CD68      mean      CD68
# mean_Ki67      mean      Ki67

# %% [markdown]
# This shall suffice for now
